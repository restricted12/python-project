# %%
import requests

# Define the API URL and key
api_key = "874ded9d"  # Replace with your actual OMDB API key
api_url = "http://www.omdbapi.com/"

# Get movie title from user input
movie_title = input("Enter the title of the movie you want to search for: ")

# Define the parameters for the API request
params = {
    "apikey": api_key,
    "t": movie_title  # Use the user-provided title
}

# Make the API request
response = requests.get(api_url, params=params)
print(requests.get(json))
# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
    # Print the details from the response
    if data.get("Response") == "True":  # Check if the movie was found
        print("Title:", data.get("Title"))
        print("Year:", data.get("Year"))
        print("Poster URL:", data.get("Poster"))
        print("Plot:", data.get("Plot"))
        print("Genre:", data.get("Genre"))
    else:
        print("Movie not found:", data.get("Error"))
else:
    print("Error:", response.status_code)

# %%
import requests

# Define the API URL and key
api_key = "874ded9d"  # Replace with your actual OMDB API key
api_url = "http://www.omdbapi.com/"

# Get movie title from user input
movie_title = input("Enter movie title: ")

# Define the parameters for the API request
params = {
    "apikey": api_key,
    "t": movie_title  # Use the user-provided title
}

# Make the API request
response = requests.get(api_url, params=params)

# Print the raw JSON response for debugging (optional)
# print(response.json())

# Check if the request was successful
# if response.status_code == 200:
data = response.json()
print(data)
    # Print the details from the response
#     if data.get("Response") == "True":  # Check if the movie was found
#         print("Title:", data.get("Title"))
#         print("Year:", data.get("Year"))
#         print("Poster URL:", data.get("Poster"))
#         print("Plot:", data.get("Plot"))
#         print("Genre:", data.get("Genre"))
# print("Ratings:", data.get("Ratings["Value"]"))
#     else:
#         print("Movie not found:", data.get("Error"))
# else:
#     print("Error:", response.status_code)

# %%
import requests

# Define the API URL and key
api_key = "874ded9d"  # Replace with your actual OMDB API key
api_url = "http://www.omdbapi.com/"

# Get movie title from user input
movie_title = input("Enter movie title: ")

# Define the parameters for the API request
params = {
    "apikey": api_key,
    "t": movie_title  # Use the user-provided title
}

# Make the API request
response = requests.get(api_url, params=params)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    
    # # Print the details from the response
    # if data.get("Response") == "True":  # Check if the movie was found
    #     print("Title:", data.get("Title"))
    #     print("Year:", data.get("Year"))
    #     print("Poster URL:", data.get("Poster"))
    #     print("Plot:", data.get("Plot"))
    #     print("Genre:", data.get("Genre"))
        
        # Find and print the IMDb rating
ratings = data.get("Ratings", [])
imdb_rating = 'N/A'  # Default value if IMDb rating is not found
for rating in ratings:
    if rating['Source'] == 'Internet Movie Database':
        imdb_rating = rating['Value']
        print("IMDb Rating:", imdb_rating)
        break
        
        
    

    
        
        
        
        
#     else:
#         print("Movie not found:", data.get("Error"))
# else:
#     print("Error:", response.status_code)
